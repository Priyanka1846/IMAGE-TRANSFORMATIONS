# %% [markdown]
# ## EXP 4
#
# # Image transformations
#
# **Name:** Priyanka K
#
# **Reg No:** 212223230162
#
# **Slot:** 4I5-2

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread('nature.jpg')

# %%
img.shape
# Out:
# (382, 612, 3)

# %%
plt.imshow(img[:,:,::-1])
plt.title('Original image')
plt.show()

# %%
# i) Image translation

tx,ty=200,400
trans=np.float32([[1,0,tx],[0,1,ty]])
trans_img=cv2.warpAffine(img,trans,(1536,1024))

# %%
plt.imshow(trans_img[:,:,::-1])
plt.title('Translated Image')
plt.axis('on')
plt.show()

# %%
# Image Scaling 

fx,fy=3.0,1.0
scaled=cv2.resize(img,None,fx=fx,fy=fy, interpolation=cv2.INTER_LINEAR)

# %%
plt.imshow(scaled[:,:,::-1])
plt.title('Scaled Image')
plt.axis('on')
plt.show()

# %%
# Image Shearing

shear_matrix=np.float32([[1,0.7,0],[0.7,1,0]])
shaer_img=cv2.warpAffine(img,shear_matrix,(1536,1024))

# %%
plt.imshow(shaer_img[:,:,::-1])
plt.title("Sheared Image")
plt.axis('on')
plt.show()

# %%
# Image Reflection 

reflected=cv2.flip(img,2)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.title('Original Image')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(reflected[:,:,::-1])
plt.title('Reflected Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Image Rotation

(height,width)=img.shape[:2]
angle=45
center=(width//2,height//2)
rot=cv2.getRotationMatrix2D(center,angle,1)
rot_img=cv2.warpAffine(img,rot,(width,height))

# %%
plt.imshow(cv2.cvtColor(rot_img, cv2.COLOR_BGR2RGB))
plt.title("Rotated Image")
plt.axis('off')
# Out:
# (-0.5, 611.5, 381.5, -0.5)

# %%
x,y,w,h=50,600,1000,400
cropped = img[100:500, 50:100]
cropped=img[y:y+h,x:x+w]

# %%
plt.figure(figsize=(10, 5))

# Plot the original image in the first subplot
plt.subplot(1, 2, 1)
plt.imshow(img[:, :, ::-1])
plt.title("Original Image")
plt.axis('on')

# Plot the cropped image in the second subplot
plt.subplot(1, 2, 2)
plt.imshow(cropped[:, :, ::-1])
print("Shape of cropped image:", cropped.shape)
plt.title("Cropped Image")
plt.axis('on')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 11
#       9 # Plot the cropped image in the second subplot
#      10 plt.subplot(1, 2, 2)
# ---> 11 plt.imshow(cropped[:, :, ::-1])
#      12 print("Shape of cropped image:", cropped.shape)
#      13 plt.title("Cropped Image")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
# ...
